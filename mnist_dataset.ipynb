# %%
# !cd /content/drive/MyDrive/federated_learning/MNIST

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
import numpy as np
import copy
import random
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, confusion_matrix, ConfusionMatrixDisplay
from itertools import cycle
import seaborn as sns
import uuid

# %%
# Configs
NUM_CLIENTS = 5
NUM_EPOCHS = 30
BATCH_SIZE = 64
LEARNING_RATE = 0.001
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %%
# Transforms
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# %%
# Load MNIST and split into train/validation/test
dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST(root='./data', train=False, transform=transform)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 17.8MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 483kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.47MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.99MB/s]

# %%
# Split train dataset into train and validation
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
# CNN Model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.net = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3), nn.ReLU(), nn.MaxPool2d(2),
            nn.Flatten(),
            nn.Linear(64 * 5 * 5, 128), nn.ReLU(),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        return self.net(x)

# %%
# LeNet Model
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        self.net = nn.Sequential(
            nn.Conv2d(1, 6, kernel_size=5, padding=2), nn.ReLU(), nn.AvgPool2d(2),
            nn.Conv2d(6, 16, kernel_size=5), nn.ReLU(), nn.AvgPool2d(2),
            nn.Flatten(),
            nn.Linear(16 * 5 * 5, 120), nn.ReLU(),
            nn.Linear(120, 84), nn.ReLU(),
            nn.Linear(84, 10)
        )

    def forward(self, x):
        return self.net(x)

# %%
# Dataset Split
def split_dataset(dataset, num_clients):
    size = len(dataset) // num_clients
    indices = np.random.permutation(len(dataset))
    return [Subset(dataset, indices[i * size:(i + 1) * size]) for i in range(num_clients)]

client_datasets = split_dataset(train_dataset, NUM_CLIENTS)

# %%
# Metrics Tracking
def compute_metrics(model, loader):
    model.eval()
    correct = 0
    total = 0
    loss = 0.0
    all_preds = []
    all_labels = []
    all_probs = []

    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            preds = model(x)
            loss += F.cross_entropy(preds, y, reduction='sum').item()
            pred_labels = preds.argmax(dim=1)
            correct += (pred_labels == y).sum().item()
            total += y.size(0)
            all_preds.extend(pred_labels.cpu().numpy())
            all_labels.extend(y.cpu().numpy())
            all_probs.extend(F.softmax(preds, dim=1).cpu().numpy())

    accuracy = 100. * correct / total
    avg_loss = loss / total
    return accuracy, avg_loss, np.array(all_labels), np.array(all_preds), np.array(all_probs)

# %%
# Plotting Functions
def plot_metrics(train_metrics, val_metrics, test_metrics, model_name, method):
    epochs = range(1, NUM_EPOCHS + 1)

    # Accuracy Plot
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_metrics['acc'], label='Train Accuracy')
    plt.plot(epochs, val_metrics['acc'], label='Validation Accuracy')
    plt.plot(epochs, test_metrics['acc'], label='Test Accuracy')
    plt.title(f'{model_name} {method} Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'{model_name}_{method}_accuracy.png')
    plt.close()

    # Loss Plot
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_metrics['loss'], label='Train Loss')
    plt.plot(epochs, val_metrics['loss'], label='Validation Loss')
    plt.plot(epochs, test_metrics['loss'], label='Test Loss')
    plt.title(f'{model_name} {method} Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'{model_name}_{method}_loss.png')
    plt.close()

def plot_roc_curve(labels, probs, model_name, method):
    plt.figure(figsize=(10, 6))
    colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'navy', 'deeppink', 'cyan', 'magenta', 'yellow', 'lime', 'red'])

    for i in range(10):
        fpr, tpr, _ = roc_curve(labels == i, probs[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, color=next(colors), lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'{model_name} {method} ROC Curve')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.savefig(f'{model_name}_{method}_roc.png')
    plt.close()

def plot_confusion_matrix(labels, preds, model_name, method):
    cm = confusion_matrix(labels, preds)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'{model_name} {method} Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.savefig(f'{model_name}_{method}_cm.png')
    plt.close()

# %%
# FedAvg Training
def fedavg_train(model_class, model_name):
    global_model = model_class().to(DEVICE)
    print(f"\n🔁 Training FedAvg with {model_name} on MNIST")

    train_metrics = {'acc': [], 'loss': []}
    val_metrics = {'acc': [], 'loss': []}
    test_metrics = {'acc': [], 'loss': []}

    for epoch in range(NUM_EPOCHS):
        local_weights = []
        for client_data in client_datasets:
            model = copy.deepcopy(global_model)
            model.to(DEVICE)
            optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
            loader = DataLoader(client_data, batch_size=BATCH_SIZE, shuffle=True)
            model.train()
            for x, y in loader:
                x, y = x.to(DEVICE), y.to(DEVICE)
                optimizer.zero_grad()
                preds = model(x)
                loss = F.cross_entropy(preds, y)
                loss.backward()
                optimizer.step()
            local_weights.append(copy.deepcopy(model.state_dict()))

        global_model.load_state_dict(average_weights(local_weights))

        # Compute metrics
        train_acc, train_loss, _, _, _ = compute_metrics(global_model, train_loader)
        val_acc, val_loss, _, _, _ = compute_metrics(global_model, val_loader)
        test_acc, test_loss, labels, preds, probs = compute_metrics(global_model, test_loader)

        train_metrics['acc'].append(train_acc)
        train_metrics['loss'].append(train_loss)
        val_metrics['acc'].append(val_acc)
        val_metrics['loss'].append(val_loss)
        test_metrics['acc'].append(test_acc)
        test_metrics['loss'].append(test_loss)

        print(f"Epoch {epoch+1}, FedAvg {model_name} - Train Acc: {train_acc:.2f}%, Val Acc: {val_acc:.2f}%, Test Acc: {test_acc:.2f}%")

        # Plot ROC and Confusion Matrix for final epoch
        if epoch == NUM_EPOCHS - 1:
            plot_roc_curve(labels, probs, model_name, 'FedAvg')
            plot_confusion_matrix(labels, preds, model_name, 'FedAvg')

    plot_metrics(train_metrics, val_metrics, test_metrics, model_name, 'FedAvg')
    return global_model, test_metrics['acc'][-1]

# %%
# FML-Proxy Training
def fml_proxy_train(model_class, model_name):
    print(f"\n🔁 Training FML-Proxy with {model_name} on MNIST")
    priv_models = [model_class().to(DEVICE) for _ in range(NUM_CLIENTS)]
    proxy_models = [model_class().to(DEVICE) for _ in range(NUM_CLIENTS)]

    train_metrics = {'acc': [], 'loss': []}
    val_metrics = {'acc': [], 'loss': []}
    test_metrics = {'acc': [], 'loss': []}

    for epoch in range(NUM_EPOCHS):
        for i in range(NUM_CLIENTS):
            client_data = client_datasets[i]
            priv = priv_models[i]
            proxy = proxy_models[i]

            priv.train()
            proxy.train()

            priv_opt = torch.optim.Adam(priv.parameters(), lr=LEARNING_RATE)
            proxy_opt = torch.optim.Adam(proxy.parameters(), lr=LEARNING_RATE)
            loader = DataLoader(client_data, batch_size=BATCH_SIZE, shuffle=True)

            for x, y in loader:
                x, y = x.to(DEVICE), y.to(DEVICE)

                # Proxy update using ensemble
                with torch.no_grad():
                    ensemble = torch.zeros(x.size(0), 10).to(DEVICE)
                    for j, other in enumerate(priv_models):
                        if j != i:
                            other.eval()
                            ensemble += F.softmax(other(x), dim=1)
                    ensemble /= (NUM_CLIENTS - 1)

                proxy_logits = proxy(x)
                loss_proxy = F.kl_div(F.log_softmax(proxy_logits, dim=1), ensemble, reduction='batchmean')
                proxy_opt.zero_grad()
                loss_proxy.backward()
                proxy_opt.step()

                # Private update using proxy + true labels
                priv_logits = priv(x)
                with torch.no_grad():
                    proxy_logits = proxy(x)

                loss_kd = F.kl_div(F.log_softmax(priv_logits, dim=1),
                                 F.softmax(proxy_logits, dim=1), reduction='batchmean')
                loss_ce = F.cross_entropy(priv_logits, y)
                loss = 0.7 * loss_kd + 0.3 * loss_ce

                priv_opt.zero_grad()
                loss.backward()
                priv_opt.step()

        # Compute average metrics across clients
        train_accs, train_losses = [], []
        val_accs, val_losses = [], []
        test_accs, test_losses = [], []
        all_labels, all_preds, all_probs = [], [], []

        for priv in priv_models:
            train_acc, train_loss, _, _, _ = compute_metrics(priv, train_loader)
            val_acc, val_loss, _, _, _ = compute_metrics(priv, val_loader)
            test_acc, test_loss, labels, preds, probs = compute_metrics(priv, test_loader)

            train_accs.append(train_acc)
            train_losses.append(train_loss)
            val_accs.append(val_acc)
            val_losses.append(val_loss)
            test_accs.append(test_acc)
            test_losses.append(test_loss)
            all_labels.extend(labels)
            all_preds.extend(preds)
            all_probs.extend(probs)

        train_metrics['acc'].append(np.mean(train_accs))
        train_metrics['loss'].append(np.mean(train_losses))
        val_metrics['acc'].append(np.mean(val_accs))
        val_metrics['loss'].append(np.mean(val_losses))
        test_metrics['acc'].append(np.mean(test_accs))
        test_metrics['loss'].append(np.mean(test_losses))

        print(f"Epoch {epoch+1}, FML-Proxy {model_name} - Train Acc: {np.mean(train_accs):.2f}%, Val Acc: {np.mean(val_accs):.2f}%, Test Acc: {np.mean(test_accs):.2f}%")

        # Plot ROC and Confusion Matrix for final epoch
        if epoch == NUM_EPOCHS - 1:
            plot_roc_curve(np.array(all_labels), np.array(all_probs), model_name, 'FML-Proxy')
            plot_confusion_matrix(np.array(all_labels), np.array(all_preds), model_name, 'FML-Proxy')

    plot_metrics(train_metrics, val_metrics, test_metrics, model_name, 'FML-Proxy')
    return priv_models, np.mean(test_accs)

# %%
# FedAvg Aggregation
def average_weights(state_dicts):
    avg = copy.deepcopy(state_dicts[0])
    for k in avg.keys():
        for i in range(1, len(state_dicts)):
            avg[k] += state_dicts[i][k]
        avg[k] = avg[k] / len(state_dicts)
    return avg

# %%
# Train and Compare
def compare_models():
    print("\n🚀 Training and Comparing CNN and LeNet")

    # Train CNN
    cnn_fed_model, cnn_fed_acc = fedavg_train(CNN, "CNN")
    cnn_fml_models, cnn_fml_acc = fml_proxy_train(CNN, "CNN")

    # Train LeNet
    lenet_fed_model, lenet_fed_acc = fedavg_train(LeNet, "LeNet")
    lenet_fml_models, lenet_fml_acc = fml_proxy_train(LeNet, "LeNet")

    # Comparison
    print(f"\n✅ Final Results:")
    print(f"CNN FedAvg Test Accuracy: {cnn_fed_acc:.2f}%")
    print(f"CNN FML-Proxy Average Test Accuracy: {cnn_fml_acc:.2f}%")
    print(f"LeNet FedAvg Test Accuracy: {lenet_fed_acc:.2f}%")
    print(f"LeNet FML-Proxy Average Test Accuracy: {lenet_fml_acc:.2f}%")

    # Bar Plot for Comparison
    models = ['CNN FedAvg', 'CNN FML-Proxy', 'LeNet FedAvg', 'LeNet FML-Proxy']
    accuracies = [cnn_fed_acc, cnn_fml_acc, lenet_fed_acc, lenet_fml_acc]

    plt.figure(figsize=(10, 6))
    sns.barplot(x=models, y=accuracies)
    plt.title('Model Comparison - Test Accuracy')
    plt.ylabel('Test Accuracy (%)')
    plt.xticks(rotation=45)
    plt.savefig('model_comparison.png')
    plt.close()

# %%
# Run the comparison
compare_models()
# Out:
# 🚀 Training and Comparing CNN and LeNet
#
# 🔁 Training FedAvg with CNN on MNIST
# Epoch 1, FedAvg CNN - Train Acc: 95.13%, Val Acc: 95.19%, Test Acc: 95.23%
# Epoch 2, FedAvg CNN - Train Acc: 97.89%, Val Acc: 97.48%, Test Acc: 98.17%
# Epoch 3, FedAvg CNN - Train Acc: 98.56%, Val Acc: 98.32%, Test Acc: 98.68%
# Epoch 4, FedAvg CNN - Train Acc: 98.83%, Val Acc: 98.49%, Test Acc: 98.82%
# Epoch 5, FedAvg CNN - Train Acc: 99.07%, Val Acc: 98.62%, Test Acc: 98.82%
# Epoch 6, FedAvg CNN - Train Acc: 99.23%, Val Acc: 98.84%, Test Acc: 99.03%
# Epoch 7, FedAvg CNN - Train Acc: 99.36%, Val Acc: 98.80%, Test Acc: 98.98%
# Epoch 8, FedAvg CNN - Train Acc: 99.50%, Val Acc: 98.86%, Test Acc: 98.99%
# Epoch 9, FedAvg CNN - Train Acc: 99.54%, Val Acc: 98.98%, Test Acc: 99.20%
# Epoch 10, FedAvg CNN - Train Acc: 99.60%, Val Acc: 99.00%, Test Acc: 99.13%
# Epoch 11, FedAvg CNN - Train Acc: 99.64%, Val Acc: 98.89%, Test Acc: 99.17%
# Epoch 12, FedAvg CNN - Train Acc: 99.73%, Val Acc: 99.03%, Test Acc: 99.14%
# Epoch 13, FedAvg CNN - Train Acc: 99.79%, Val Acc: 99.09%, Test Acc: 99.29%
# Epoch 14, FedAvg CNN - Train Acc: 99.77%, Val Acc: 99.08%, Test Acc: 99.18%
# Epoch 15, FedAvg CNN - Train Acc: 99.79%, Val Acc: 99.05%, Test Acc: 99.18%
# Epoch 16, FedAvg CNN - Train Acc: 99.82%, Val Acc: 99.02%, Test Acc: 99.26%
# Epoch 17, FedAvg CNN - Train Acc: 99.86%, Val Acc: 99.13%, Test Acc: 99.24%
# Epoch 18, FedAvg CNN - Train Acc: 99.88%, Val Acc: 99.12%, Test Acc: 99.27%
# Epoch 19, FedAvg CNN - Train Acc: 99.89%, Val Acc: 99.04%, Test Acc: 99.36%
# Epoch 20, FedAvg CNN - Train Acc: 99.89%, Val Acc: 99.10%, Test Acc: 99.26%
# Epoch 21, FedAvg CNN - Train Acc: 99.89%, Val Acc: 99.15%, Test Acc: 99.26%
# Epoch 22, FedAvg CNN - Train Acc: 99.92%, Val Acc: 99.15%, Test Acc: 99.33%
# Epoch 23, FedAvg CNN - Train Acc: 99.94%, Val Acc: 99.12%, Test Acc: 99.27%
# Epoch 24, FedAvg CNN - Train Acc: 99.93%, Val Acc: 99.14%, Test Acc: 99.34%
# Epoch 25, FedAvg CNN - Train Acc: 99.95%, Val Acc: 99.09%, Test Acc: 99.28%
# Epoch 26, FedAvg CNN - Train Acc: 99.92%, Val Acc: 99.10%, Test Acc: 99.18%
# Epoch 27, FedAvg CNN - Train Acc: 99.93%, Val Acc: 99.08%, Test Acc: 99.25%
# Epoch 28, FedAvg CNN - Train Acc: 99.95%, Val Acc: 99.08%, Test Acc: 99.32%
# Epoch 29, FedAvg CNN - Train Acc: 99.94%, Val Acc: 99.08%, Test Acc: 99.32%
# Epoch 30, FedAvg CNN - Train Acc: 99.95%, Val Acc: 99.17%, Test Acc: 99.32%
#
# 🔁 Training FML-Proxy with CNN on MNIST
# Epoch 1, FML-Proxy CNN - Train Acc: 96.77%, Val Acc: 96.63%, Test Acc: 97.13%
# Epoch 2, FML-Proxy CNN - Train Acc: 97.46%, Val Acc: 97.32%, Test Acc: 97.58%
# Epoch 3, FML-Proxy CNN - Train Acc: 97.86%, Val Acc: 97.75%, Test Acc: 98.03%
# Epoch 4, FML-Proxy CNN - Train Acc: 98.08%, Val Acc: 97.95%, Test Acc: 98.22%
# Epoch 5, FML-Proxy CNN - Train Acc: 98.24%, Val Acc: 98.03%, Test Acc: 98.27%
# Epoch 6, FML-Proxy CNN - Train Acc: 98.30%, Val Acc: 98.12%, Test Acc: 98.27%
# Epoch 7, FML-Proxy CNN - Train Acc: 98.36%, Val Acc: 98.18%, Test Acc: 98.40%
# Epoch 8, FML-Proxy CNN - Train Acc: 98.38%, Val Acc: 98.15%, Test Acc: 98.45%
# Epoch 9, FML-Proxy CNN - Train Acc: 98.42%, Val Acc: 98.14%, Test Acc: 98.41%
# Epoch 10, FML-Proxy CNN - Train Acc: 98.37%, Val Acc: 98.13%, Test Acc: 98.34%
# Epoch 11, FML-Proxy CNN - Train Acc: 98.41%, Val Acc: 98.16%, Test Acc: 98.40%
# Epoch 12, FML-Proxy CNN - Train Acc: 98.43%, Val Acc: 98.17%, Test Acc: 98.43%
# Epoch 13, FML-Proxy CNN - Train Acc: 98.42%, Val Acc: 98.20%, Test Acc: 98.36%
# Epoch 14, FML-Proxy CNN - Train Acc: 98.44%, Val Acc: 98.17%, Test Acc: 98.35%
# Epoch 15, FML-Proxy CNN - Train Acc: 98.52%, Val Acc: 98.28%, Test Acc: 98.48%
# Epoch 16, FML-Proxy CNN - Train Acc: 98.52%, Val Acc: 98.28%, Test Acc: 98.45%
# Epoch 17, FML-Proxy CNN - Train Acc: 98.47%, Val Acc: 98.16%, Test Acc: 98.37%
# Epoch 18, FML-Proxy CNN - Train Acc: 98.54%, Val Acc: 98.26%, Test Acc: 98.48%
# Epoch 19, FML-Proxy CNN - Train Acc: 98.62%, Val Acc: 98.32%, Test Acc: 98.55%
# Epoch 20, FML-Proxy CNN - Train Acc: 98.51%, Val Acc: 98.24%, Test Acc: 98.49%
# Epoch 21, FML-Proxy CNN - Train Acc: 98.53%, Val Acc: 98.25%, Test Acc: 98.48%
# Epoch 22, FML-Proxy CNN - Train Acc: 98.55%, Val Acc: 98.30%, Test Acc: 98.54%
# Epoch 23, FML-Proxy CNN - Train Acc: 98.54%, Val Acc: 98.30%, Test Acc: 98.55%
# Epoch 24, FML-Proxy CNN - Train Acc: 98.57%, Val Acc: 98.25%, Test Acc: 98.56%
# Epoch 25, FML-Proxy CNN - Train Acc: 98.54%, Val Acc: 98.24%, Test Acc: 98.57%
# Epoch 26, FML-Proxy CNN - Train Acc: 98.57%, Val Acc: 98.30%, Test Acc: 98.57%
# Epoch 27, FML-Proxy CNN - Train Acc: 98.60%, Val Acc: 98.28%, Test Acc: 98.50%
# Epoch 28, FML-Proxy CNN - Train Acc: 98.57%, Val Acc: 98.28%, Test Acc: 98.57%
# Epoch 29, FML-Proxy CNN - Train Acc: 98.59%, Val Acc: 98.30%, Test Acc: 98.56%
# Epoch 30, FML-Proxy CNN - Train Acc: 98.57%, Val Acc: 98.33%, Test Acc: 98.54%
#
# 🔁 Training FedAvg with LeNet on MNIST
# Epoch 1, FedAvg LeNet - Train Acc: 90.82%, Val Acc: 89.95%, Test Acc: 90.70%
# Epoch 2, FedAvg LeNet - Train Acc: 94.56%, Val Acc: 94.28%, Test Acc: 94.77%
# Epoch 3, FedAvg LeNet - Train Acc: 96.12%, Val Acc: 95.76%, Test Acc: 96.26%
# Epoch 4, FedAvg LeNet - Train Acc: 96.83%, Val Acc: 96.44%, Test Acc: 96.76%
# Epoch 5, FedAvg LeNet - Train Acc: 97.40%, Val Acc: 96.92%, Test Acc: 97.44%
# Epoch 6, FedAvg LeNet - Train Acc: 97.84%, Val Acc: 97.40%, Test Acc: 97.89%
# Epoch 7, FedAvg LeNet - Train Acc: 98.05%, Val Acc: 97.69%, Test Acc: 97.98%
# Epoch 8, FedAvg LeNet - Train Acc: 98.29%, Val Acc: 97.90%, Test Acc: 98.22%
# Epoch 9, FedAvg LeNet - Train Acc: 98.37%, Val Acc: 97.97%, Test Acc: 98.28%
# Epoch 10, FedAvg LeNet - Train Acc: 98.54%, Val Acc: 98.25%, Test Acc: 98.58%
# Epoch 11, FedAvg LeNet - Train Acc: 98.68%, Val Acc: 98.41%, Test Acc: 98.58%
# Epoch 12, FedAvg LeNet - Train Acc: 98.81%, Val Acc: 98.49%, Test Acc: 98.60%
# Epoch 13, FedAvg LeNet - Train Acc: 98.91%, Val Acc: 98.46%, Test Acc: 98.73%
# Epoch 14, FedAvg LeNet - Train Acc: 99.01%, Val Acc: 98.57%, Test Acc: 98.82%
# Epoch 15, FedAvg LeNet - Train Acc: 99.03%, Val Acc: 98.70%, Test Acc: 98.89%
# Epoch 16, FedAvg LeNet - Train Acc: 98.98%, Val Acc: 98.51%, Test Acc: 98.74%
# Epoch 17, FedAvg LeNet - Train Acc: 99.18%, Val Acc: 98.74%, Test Acc: 99.05%
# Epoch 18, FedAvg LeNet - Train Acc: 99.27%, Val Acc: 98.81%, Test Acc: 99.01%
# Epoch 19, FedAvg LeNet - Train Acc: 99.31%, Val Acc: 98.83%, Test Acc: 98.91%
# Epoch 20, FedAvg LeNet - Train Acc: 99.38%, Val Acc: 98.89%, Test Acc: 98.98%
# Epoch 21, FedAvg LeNet - Train Acc: 99.43%, Val Acc: 98.86%, Test Acc: 98.98%
# Epoch 22, FedAvg LeNet - Train Acc: 99.44%, Val Acc: 98.93%, Test Acc: 99.05%
# Epoch 23, FedAvg LeNet - Train Acc: 99.44%, Val Acc: 98.92%, Test Acc: 99.04%
# Epoch 24, FedAvg LeNet - Train Acc: 99.53%, Val Acc: 98.98%, Test Acc: 99.16%
# Epoch 25, FedAvg LeNet - Train Acc: 99.48%, Val Acc: 98.94%, Test Acc: 99.00%
# Epoch 26, FedAvg LeNet - Train Acc: 99.56%, Val Acc: 99.08%, Test Acc: 99.07%
# Epoch 27, FedAvg LeNet - Train Acc: 99.59%, Val Acc: 99.04%, Test Acc: 99.05%
# Epoch 28, FedAvg LeNet - Train Acc: 99.61%, Val Acc: 99.05%, Test Acc: 99.04%
# Epoch 29, FedAvg LeNet - Train Acc: 99.63%, Val Acc: 99.01%, Test Acc: 99.07%
# Epoch 30, FedAvg LeNet - Train Acc: 99.63%, Val Acc: 99.00%, Test Acc: 99.11%
#
# 🔁 Training FML-Proxy with LeNet on MNIST
# Epoch 1, FML-Proxy LeNet - Train Acc: 91.54%, Val Acc: 91.30%, Test Acc: 91.99%
# Epoch 2, FML-Proxy LeNet - Train Acc: 93.88%, Val Acc: 93.66%, Test Acc: 94.16%
# Epoch 3, FML-Proxy LeNet - Train Acc: 94.98%, Val Acc: 94.68%, Test Acc: 95.19%
# Epoch 4, FML-Proxy LeNet - Train Acc: 95.70%, Val Acc: 95.41%, Test Acc: 95.85%
# Epoch 5, FML-Proxy LeNet - Train Acc: 96.18%, Val Acc: 95.94%, Test Acc: 96.30%
# Epoch 6, FML-Proxy LeNet - Train Acc: 96.66%, Val Acc: 96.38%, Test Acc: 96.70%
# Epoch 7, FML-Proxy LeNet - Train Acc: 96.93%, Val Acc: 96.61%, Test Acc: 96.98%
# Epoch 8, FML-Proxy LeNet - Train Acc: 97.23%, Val Acc: 96.87%, Test Acc: 97.23%
# Epoch 9, FML-Proxy LeNet - Train Acc: 97.33%, Val Acc: 97.04%, Test Acc: 97.37%
# Epoch 10, FML-Proxy LeNet - Train Acc: 97.36%, Val Acc: 97.14%, Test Acc: 97.38%
# Epoch 11, FML-Proxy LeNet - Train Acc: 97.55%, Val Acc: 97.22%, Test Acc: 97.60%
# Epoch 12, FML-Proxy LeNet - Train Acc: 97.74%, Val Acc: 97.34%, Test Acc: 97.68%
# Epoch 13, FML-Proxy LeNet - Train Acc: 97.72%, Val Acc: 97.32%, Test Acc: 97.74%
# Epoch 14, FML-Proxy LeNet - Train Acc: 97.85%, Val Acc: 97.49%, Test Acc: 97.88%
# Epoch 15, FML-Proxy LeNet - Train Acc: 97.89%, Val Acc: 97.57%, Test Acc: 97.92%
# Epoch 16, FML-Proxy LeNet - Train Acc: 98.01%, Val Acc: 97.71%, Test Acc: 98.08%
# Epoch 17, FML-Proxy LeNet - Train Acc: 98.13%, Val Acc: 97.89%, Test Acc: 98.14%
# Epoch 18, FML-Proxy LeNet - Train Acc: 98.09%, Val Acc: 97.75%, Test Acc: 98.09%
# Epoch 19, FML-Proxy LeNet - Train Acc: 98.14%, Val Acc: 97.72%, Test Acc: 98.16%
# Epoch 20, FML-Proxy LeNet - Train Acc: 98.08%, Val Acc: 97.73%, Test Acc: 98.12%
# Epoch 21, FML-Proxy LeNet - Train Acc: 98.15%, Val Acc: 97.87%, Test Acc: 98.24%
# Epoch 22, FML-Proxy LeNet - Train Acc: 98.14%, Val Acc: 97.85%, Test Acc: 98.19%
# Epoch 23, FML-Proxy LeNet - Train Acc: 98.27%, Val Acc: 97.94%, Test Acc: 98.21%
# Epoch 24, FML-Proxy LeNet - Train Acc: 98.29%, Val Acc: 97.97%, Test Acc: 98.27%
# Epoch 25, FML-Proxy LeNet - Train Acc: 98.26%, Val Acc: 98.00%, Test Acc: 98.24%
# Epoch 26, FML-Proxy LeNet - Train Acc: 98.27%, Val Acc: 98.02%, Test Acc: 98.28%
# Epoch 27, FML-Proxy LeNet - Train Acc: 98.32%, Val Acc: 98.03%, Test Acc: 98.27%
# Epoch 28, FML-Proxy LeNet - Train Acc: 98.40%, Val Acc: 98.04%, Test Acc: 98.29%
# Epoch 29, FML-Proxy LeNet - Train Acc: 98.34%, Val Acc: 98.03%, Test Acc: 98.28%
# Epoch 30, FML-Proxy LeNet - Train Acc: 98.37%, Val Acc: 98.03%, Test Acc: 98.26%
#
# ✅ Final Results:
# CNN FedAvg Test Accuracy: 99.32%
# CNN FML-Proxy Average Test Accuracy: 98.54%
# LeNet FedAvg Test Accuracy: 99.11%
# LeNet FML-Proxy Average Test Accuracy: 98.26%

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

def display_plots(dataset='mnist'):
    # Define models and methods
    models = ['CNN', 'LeNet']
    methods = ['FedAvg', 'FML-Proxy']
    metrics = ['accuracy', 'loss', 'roc', 'cm']  # Adjust metrics based on your code

    # Directory where plots are saved
    plot_dir = '/content'  # Update if plots are saved elsewhere (e.g., './plots/')

    # Loop through all combinations
    for model in models:
        for method in methods:
            for metric in metrics:
                # Construct plot filename based on your naming convention
                plot_file = f"{model}_{method}_{metric}.png"
                plot_path = os.path.join(plot_dir, plot_file)

                # Check if the plot exists
                if os.path.exists(plot_path):
                    print(f"Displaying: {plot_file}")
                    # Load and display the image
                    img = Image.open(plot_path)
                    plt.figure(figsize=(8, 6))
                    plt.imshow(img)
                    plt.axis('off')  # Hide axes
                    plt.title(plot_file)
                    plt.show()
                else:
                    print(f"Plot not found: {plot_file}")

# Call the function to display MNIST plots
display_plots(dataset='mnist')
# Out:
# Displaying: CNN_FedAvg_accuracy.png
# Displaying: CNN_FedAvg_loss.png
# Displaying: CNN_FedAvg_roc.png
# Displaying: CNN_FedAvg_cm.png
# Displaying: CNN_FML-Proxy_accuracy.png
# Displaying: CNN_FML-Proxy_loss.png
# Displaying: CNN_FML-Proxy_roc.png
# Displaying: CNN_FML-Proxy_cm.png
# Displaying: LeNet_FedAvg_accuracy.png
# Displaying: LeNet_FedAvg_loss.png
# Displaying: LeNet_FedAvg_roc.png
# Displaying: LeNet_FedAvg_cm.png
# Displaying: LeNet_FML-Proxy_accuracy.png
# Displaying: LeNet_FML-Proxy_loss.png
# Displaying: LeNet_FML-Proxy_roc.png
# Displaying: LeNet_FML-Proxy_cm.png
